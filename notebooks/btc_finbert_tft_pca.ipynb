# %%
# !pip install transformers torch --quiet
# !pip install kagglehub textblob nltk scikit-learn scipy --quiet

# %%
# !python btc_sentiment_finbert_pca_v3.py
# Out:
# 🖥️ Dispositivo: cuda
#    GPU: Tesla T4
# ...
# BTC SENTIMENT ANALYSIS - FinBERT + PCA (v3.0)
# ...
#
# 📊 Configuración V3:
#    - FinBERT: ProsusAI/finbert
#    - PCA componentes: 3
#    - Device: cuda
#
# ...
# SECCIÓN 2: CARGA DE DATOS
# ...
# Using Colab cache for faster access to the 'bitcoin-sentiment-analysis-twitter-data' dataset.
# ✅ Tweets (kagglehub): /kaggle/input/bitcoin-sentiment-analysis-twitter-data/bitcoin_tweets1000000.csv
#    Shape tweets original: (1000025, 17)
# ✅ OHLCV: BTCUSDT_1h_2021-02-05_2021-08-21.csv
#    Shape OHLCV: (4742, 6)
#
# ...
# SECCIÓN 3: PREPROCESAMIENTO
# ...
#    Columna temporal: date
#    Columna texto: cleanText
#    Tweets tras limpieza: 904,427
#
# ...
# SECCIÓN 4: ANÁLISIS DE SENTIMIENTO (Multi-Método)
# ...
#
# 📊 Aplicando VADER (baseline)...
#    VADER compound mean: 0.2452
#
# 🔄 Cargando modelos Transformer...
#    Cargando ProsusAI/finbert...
# tokenizer_config.json: 100% 252/252 [00:00<00:00, 566kB/s]
# config.json: 100% 758/758 [00:00<00:00, 1.40MB/s]
# ...
