# %%
# !pip install kagglehub textblob nltk scikit-learn --quiet

# %%
# !python btc_sentiment_final_with_pca.py
# Out:
# ...
# BTC SENTIMENT ANALYSIS - RESEARCH NOTEBOOK (v2 con PCA)
# ...
#
# 📊 Configuración:
#    - Horizontes: (1, 6, 24) horas
#    - PCA: 3 componentes
#
# ...
# SECCIÓN 2: CARGA DE DATOS
# ...
# 100% 183M/183M [00:05<00:00, 33.2MB/s]
# Extracting files...
# ✅ Tweets (kagglehub): /root/.cache/kagglehub/datasets/gautamchettiar/bitcoin-sentiment-analysis-twitter-data/versions/1/bitcoin_tweets1000000.csv
#    Shape tweets: (1000025, 17)
# ✅ OHLCV: BTCUSDT_1h_2021-02-05_2021-08-21.csv
#    Shape OHLCV: (4742, 6)
#
# ...
# SECCIÓN 3: PREPROCESAMIENTO
# ...
#    Columna temporal: date
#    Columna texto: cleanText
#    Tweets tras limpieza: 905,863
#
# ...
# SECCIÓN 4: ANÁLISIS DE SENTIMIENTO
# ...
#    Calculando VADER scores...
#    Calculando TextBlob scores...
#    Tweets positivos: 479,111
#    Tweets negativos: 131,517
#    Tweets neutrales: 295,235
#
# ...
# SECCIÓN 5: AGREGACIÓN HORARIA
# ...
#    Horas con tweets: 1,523
#
# ...
# SECCIÓN 6: FEATURES TÉCNICOS
# ...
#    Shape tras features: (4742, 51)
#
# ...
# SECCIÓN 7: PCA DE VARIABLES DE SENTIMIENTO
# ...
